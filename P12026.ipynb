# %% [markdown]
# # Working with Texts
#
# This notebook introduces one of the most common early tasks in NLP: reading text from files.
#
# ## Section 1: Reading PDF Text
#
# In this section, we will use the `pypdf` library to open a PDF file and extract text from it.
#
# `pypdf` is a modern Python library for reading and manipulating PDF files. Other libraries also exist, such as `PyPDF2`, but in this notebook we will use `pypdf`.

# %% [markdown]
# ## Import the Library
#
# Before reading a PDF, we need to import `PdfReader` from `pypdf`.
#
# `PdfReader` is the class responsible for loading a PDF file and giving us access to its pages.

# %%
from pypdf import PdfReader

# %% [markdown]
# ## Open the PDF File
#
# We will work with a file named `pdfExample.pdf`.
#
# The file is opened in binary read mode using `"rb"`. PDF files are binary files, so they should not be opened in normal text mode.
#
# In the next cell, `open()` returns a buffered binary stream object. In Python, this is usually shown as `_io.BufferedReader`.
#
# This buffered reader helps Python read binary file data efficiently. `PdfReader` then uses that stream to parse the PDF structure.

# %%
pdf_file = open("./pdfExample.pdf", "rb")
print(type(pdf_file))
# Out:
# <class '_io.BufferedReader'>

# %% [markdown]
# ## Create a PDF Reader Object
#
# Now we pass the opened file into `PdfReader`.
#
# This reader object gives access to the PDF metadata and its pages.

# %%
reader = PdfReader(pdf_file)

# %% [markdown]
# ## Get the Number of Pages
#
# A PDF is made of pages. We can count how many pages exist by checking the length of `reader.pages`.

# %%
number_of_pages = len(reader.pages)
print("Number of pages:", number_of_pages)
# Out:
# Number of pages: 3

# %% [markdown]
# ## Get a Certain Page by Page Number
#
# Pages are accessed by index.
#
# Important: Python uses zero-based indexing, so:
#
# - page `0` means the first page
# - page `1` means the second page
# - page `2` means the third page
#
# In the next example, we read the first page. You can change the page number if needed.

# %%
page_number = 0
selected_page = reader.pages[page_number]
print("Selected page index:", page_number)
# Out:
# Selected page index: 0

# %% [markdown]
# ## Extract Text from the Selected Page
#
# Once we have a page object, we can call `extract_text()` to read the text content from that page.
#
# Keep in mind that PDF text extraction is not always perfect. The quality depends on how the original PDF was created.

# %%
page_text = selected_page.extract_text()
print(page_text)
# Out:
# Anime: A Global Cultural Phenomenon
#
# Introduction
#
# Anime, a distinctive style of animation that originated in Japan, has grown from a niche
# interest into a worldwide cultural and entertainment powerhouse. Characterized by vibrant
# artwork, fantastical themes, and richly developed characters, anime appeals to audiences of
# all ages. Unlike Western animation, which is often associated primarily with children’s
# entertainment, anime spans a vast range of genres — from action, romance, and science
# fiction to horror, slice-of-life, and historical drama.
#
# A Brief History
#
# The roots of anime can be traced back to the early 20th century, with short experimental
# films inspired by Western animation techniques. However, the modern anime industry began
# to take shape in the 1960s, largely due to the pioneering work of Osamu Tezuka, often called
# the God of Manga. His creation Astro Boy (1963) introduced limited animation techniques
# that allowed for storytelling on a television budget, setting a template that many studios still
# follow.
#
# The 1980s and 1990s marked a golden age for anime, with landmark films and series such as
# Akira, Dragon Ball, Sailor Moon, and Neon Genesis Evangelion. These works broke new
# ground in narrative complexity and visual ambition. The release of Hayao Miyazaki’s Spirited
# Away (2001) — which won an Academy Award for Best Animated Feature — cemented
# anime’s place in mainstream global cinema.
#
# Key Characteristics
#
# Anime is instantly recognizable by several stylistic and narrative traits:
#
# Art style: Large, expressive eyes; exaggerated facial expressions; and detailed backgrounds.
# Hair colors and designs are often unconventional, used to convey personality or symbolism.
#
# Storytelling: Serialized plots with long character arcs are common. Anime often explores
# mature themes such as existentialism, identity, loss, and morality.

# %% [markdown]
# ## Close the File
#
# Because we opened the file manually with `open()`, we should close it when we are done.
#
# Closing files is a good habit because it releases system resources.

# %%
pdf_file.close()

# %% [markdown]
# ## Recommended Safer Version
#
# A safer and more Pythonic way to work with files is to use a `with` block.
#
# This automatically closes the file after the block finishes, even if an error happens.

# %%
with open("./pdfExample.pdf", "rb") as pdf_file:
    reader = PdfReader(pdf_file)
    number_of_pages = len(reader.pages)
    page_number = 0
    selected_page = reader.pages[page_number]
    page_text = selected_page.extract_text()

    print("Buffered reader type:", type(pdf_file))
    print("Number of pages:", number_of_pages)
    print("Text from selected page:")
    print(page_text)
# Out:
# Buffered reader type: <class '_io.BufferedReader'>
# Number of pages: 3
# Text from selected page:
# Anime: A Global Cultural Phenomenon
#
# Introduction
#
# Anime, a distinctive style of animation that originated in Japan, has grown from a niche
# interest into a worldwide cultural and entertainment powerhouse. Characterized by vibrant
# artwork, fantastical themes, and richly developed characters, anime appeals to audiences of
# all ages. Unlike Western animation, which is often associated primarily with children’s
# entertainment, anime spans a vast range of genres — from action, romance, and science
# fiction to horror, slice-of-life, and historical drama.
#
# A Brief History
#
# The roots of anime can be traced back to the early 20th century, with short experimental
# films inspired by Western animation techniques. However, the modern anime industry began
# to take shape in the 1960s, largely due to the pioneering work of Osamu Tezuka, often called
# the God of Manga. His creation Astro Boy (1963) introduced limited animation techniques
# that allowed for storytelling on a television budget, setting a template that many studios still
# follow.
#
# The 1980s and 1990s marked a golden age for anime, with landmark films and series such as
# Akira, Dragon Ball, Sailor Moon, and Neon Genesis Evangelion. These works broke new
# ground in narrative complexity and visual ambition. The release of Hayao Miyazaki’s Spirited
# Away (2001) — which won an Academy Award for Best Animated Feature — cemented
# anime’s place in mainstream global cinema.
#
# Key Characteristics
#
# Anime is instantly recognizable by several stylistic and narrative traits:
#
# Art style: Large, expressive eyes; exaggerated facial expressions; and detailed backgrounds.
# Hair colors and designs are often unconventional, used to convey personality or symbolism.
#
# Storytelling: Serialized plots with long character arcs are common. Anime often explores
# mature themes such as existentialism, identity, loss, and morality.

# %% [markdown]
# ## Summary
#
# In this section, you learned how to:
#
# - import `PdfReader` from `pypdf`
# - open a PDF file in binary mode
# - understand the role of the buffered reader
# - count the number of pages
# - select a page by page number
# - extract text from that page
# - close the file correctly
#
# This is a strong first step toward working with text data from documents in NLP tasks.

# %% [markdown]
# ## Section 2: Reading Word Text
#
# In this section, we will use `python-docx` to read text from a Word file.
#
# `python-docx` is a Python library for working with Microsoft Word `.docx` files. It is a good choice when you want to open a Word document, inspect its paragraphs, and extract text.
#
# For this notebook, we will read the file `./wordExample.docx`.
#
# Unlike PDF handling, we do not need to open the file in binary mode ourselves. The `Document(...)` function handles that for us.

# %% [markdown]
# ## Import the Library
#
# We will import `Document` from `docx`.
#
# `Document` is the main class used to open and work with a `.docx` file.

# %%
from docx import Document

# %% [markdown]
# ## Open the Word File
#
# Now we open the Word document using `Document("./wordExample.docx")`.
#
# This loads the document so we can access its paragraphs and other elements.

# %%
doc = Document("./wordExample.docx")
print(type(doc))
# Out:
# <class 'docx.document.Document'>

# %% [markdown]
# ## Extract All Text
#
# A Word document usually contains its main text as a sequence of paragraphs.
#
# We can loop through `doc.paragraphs`, collect each paragraph's text, and then join everything into one string.
#
# This gives us the full document text in a form that is easy to print, search, or preprocess for NLP tasks.

# %%
all_paragraph_text = []

for paragraph in doc.paragraphs:
    all_paragraph_text.append(paragraph.text)

document_text = "\n".join(all_paragraph_text)
print(document_text)
# Out:
# Anime: A Global Cultural Phenomenon
#
# Introduction
#
# Anime, a distinctive style of animation that originated in Japan, has grown from a niche interest into a worldwide cultural and entertainment powerhouse. Characterized by vibrant artwork, fantastical themes, and richly developed characters, anime appeals to audiences of all ages. Unlike Western animation, which is often associated primarily with children’s entertainment, anime spans a vast range of genres — from action, romance, and science fiction to horror, slice-of-life, and historical drama.
#
# A Brief History
#
# The roots of anime can be traced back to the early 20th century, with short experimental films inspired by Western animation techniques. However, the modern anime industry began to take shape in the 1960s, largely due to the pioneering work of Osamu Tezuka, often called the God of Manga. His creation Astro Boy (1963) introduced limited animation techniques that allowed for storytelling on a television budget, setting a template that many studios still follow.
#
# The 1980s and 1990s marked a golden age for anime, with landmark films and series such as Akira, Dragon Ball, Sailor Moon, and Neon Genesis Evangelion. These works broke new ground in narrative complexity and visual ambition. The release of Hayao Miyazaki’s Spirited Away (2001) — which won an Academy Award for Best Animated Feature — cemented anime’s place in mainstream global cinema.
#
# Key Characteristics
#
# Anime is instantly recognizable by several stylistic and narrative traits:
#
# Art style: Large, expressive eyes; exaggerated facial expressions; and detailed backgrounds. Hair colors and designs are often unconventional, used to convey personality or symbolism.
#
# Storytelling: Serialized plots with long character arcs are common. Anime often explores mature themes such as existentialism, identity, loss, and morality.
#
# Targeted demographics: Specific terms exist for different audiences, including shonen (young boys), shojo (young girls), seinen (adult men), and josei (adult women).
#
# Fan culture: Anime has spawned a massive global community of fans, cosplayers, and creators, supported by streaming services, conventions, and online forums.
#
# Popular Genres and Examples
#
# Shonen (action-adventure): Naruto, One Piece, My Hero Academia
#
# Shojo (romance/drama): Fruits Basket, Ouran High School Host Club
#
# Isekai (parallel world): Sword Art Online, Re:Zero
#
# Slice of Life: Clannad, March Comes in Like a Lion
#
# Psychological thriller: Death Note, Monster
#
# Mecha (giant robots): Gundam, Code Geass
#
# Cultural Impact
#
# Anime has profoundly influenced global animation, filmmaking, and storytelling. Western productions like The Matrix, Stranger Things, and Cyberpunk: Edgerunners openly acknowledge anime as an inspiration. Moreover, anime has boosted tourism in Japan, with fans visiting real-life locations featured in their favorite series. The industry’s global revenue now exceeds $20 billion annually, and streaming platforms such as Crunchyroll, Netflix, and Hulu continue to invest heavily in anime production and licensing.
#
# Conclusion
#
# Anime is far more than a genre — it is a dynamic and evolving medium of artistic expression. Its ability to weave complex narratives with stunning visuals, while addressing universal human emotions, ensures its enduring popularity. Whether one is a longtime enthusiast or a curious newcomer, there is an anime for everyone.
#
# End of test document. This text is provided for layout, font, and rendering testing purposes.
#
# ---

# %% [markdown]
# ## Access a Specific Paragraph
#
# Just like a list in Python, `doc.paragraphs` can be accessed by index.
#
# This is useful when you want to inspect one part of the document at a time.

# %%
print(doc.paragraphs[0].text)
# Out:
# Anime: A Global Cultural Phenomenon

# %% [markdown]
# ## Section 3: Fetching and Processing JSON API Data with Python
#
# In this section, we will fetch data from a web API and process the JSON response.
#
# This is useful in NLP because many APIs return text data in JSON format.
#
# This section demonstrates how to:
#
# - make an HTTP request to a REST API
# - handle a JSON response
# - convert JSON into Python data
# - extract and display specific fields
#
# We will use:
#
# - `requests` to send the HTTP request
# - `json` to print the response in a readable format

# %%
import requests
import json

# %% [markdown]
# ## Fetch the API Response and Parse JSON
#
# In the next cell:
#
# - `requests.get(...)` sends a GET request to the API
# - `headers={"Accept": "application/json"}` makes it explicit that we want JSON back
# - `response.raise_for_status()` stops execution if the request fails
# - `response.json()` converts the JSON response into a Python dictionary
# - `json.dumps(..., indent=4)` formats the data to make it easier to read
#
# After that, we extract the `fact` and `length` fields from the returned data.

# %%
response = requests.get(
    url="https://catfact.ninja/fact",
    headers={"Accept": "application/json"}
)

response.raise_for_status()

fact_data = response.json()
print(json.dumps(fact_data, indent=4))

cat_fact = fact_data["fact"]
cat_fact_length = fact_data["length"]

print("\nCat fact:", cat_fact)
print("Fact length:", cat_fact_length)
