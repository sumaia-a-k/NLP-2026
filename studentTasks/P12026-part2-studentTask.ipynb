# %% [markdown]
# # P12026 Part 1: Student Task
#
# ## Task
#
# Read the text below and build a preprocessing solution that is robust enough to handle noisy writing.
#
# Then report the final count of all occurrences of the verb *to be* in this text.
#
# Return:
# - the final cleaned version of the text
# - the total count as one integer

# %% [markdown]
# ## Input Text
#
# Ystrday I was at the libary, and u'r late agian. The rooms were noizy, but the teachr said the lesson is importnt. My frend was nervus, and we are not reddy for the quiz. By noon, I was tired, but I still belive this courze will be useful.

# %%
# Write your solution here
input_text = "Ystrday I am at the libary, and u'r late agian. The rooms were noizy, but the teachr said the lesson is importnt. My frend was nervus, and we are not reddy for the quiz. By noon, I was tired, but I still belive this courze will be useful."
