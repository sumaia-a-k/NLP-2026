# %% [markdown]
# ## Session 4 Student Task: Euclidean Distance for Text Comparison
# Use the same texts from Session 4 Part 1 notebook (`sessions/session4/P42026-part1.ipynb`) and compare them using **Euclidean distance**.
#
# ### Requirements
# 1. Reuse the same text list from Part 1.
# 2. Convert the texts into vectors using `TfidfVectorizer`.
# 3. Compute Euclidean distance between the first text and all texts.
# 4. Convert distances to similarity scores and print the similarity array.

# %%
# code goes here
