# %% [markdown]
# ## Homework:
# You have the following text in the cell below, and what is required from you is:
# 1. Perform Pre-processing steps on that text.
# 2. Apply Sentiment Analysis
# 3. Apply Word Sense Disambiguation
# 4. Apply Speech Recognition

# %%
text = """I like NLP. I am exploring NLP. I am a beginner in NLP. I want to learn NLP. I like advanced NLP. I am 
learning NLP, it is very interesting and exciting. It includes machine learning and deep learning. My father
is a data scientist and he is nlp expert. My sister has good exposure into android development"""
