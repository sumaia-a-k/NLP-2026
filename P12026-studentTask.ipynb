# %% [markdown]
# # P12026 Student Task
#
# ## Instructions
#
# Answer the following 2 applied questions based on what was learned in `P12026.ipynb`.
#
# - Complete each answer in the code cells provided under each question.
# - Keep your answers clear and concise.
# - Run your code cells and keep outputs visible for grading.
# - Output may vary slightly for web-based tasks because live API responses can change.

# %% [markdown]
# ## Question 1: PDF Mini Summary
#
# Use `./pdfExample.pdf` and write code that:
#
# 1. Reads page 1 and page 2 (if page 2 exists)
# 2. Calculates how many words are in each extracted page text
# 3. Prints which page has more words
# 4. Prints the word counts for both pages

# %%
# Write your answer for Question 1 here

# %% [markdown]
# ## Question 2: Collect and Compare API Facts
#
# Write code that calls `https://catfact.ninja/fact` three times and then:
#
# 1. Handles request errors safely
# 2. Stores each returned `fact` and `length`
# 3. Prints all three facts as a numbered list
# 4. Prints the average fact length across the 3 responses

# %%
# Write your answer for Question 2 here
